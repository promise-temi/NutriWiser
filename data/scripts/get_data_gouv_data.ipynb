# %%
import requests
from pymongo import MongoClient


# URL de l’API RappelConso (données GTIN)
URL = "https://data.economie.gouv.fr/api/explore/v2.1/catalog/datasets/rappelconso-v2-gtin-espaces/exports/json"

print("[+] Téléchargement des rappels...")
response = requests.get(URL)
if response.status_code != 200:
    print(f"[-] Erreur HTTP {response.status_code}")
else: 
    data = response.json()
    print(f"[+] {len(data)} fiches récupérées")
    print(data[0:5], "\n...")  # Afficher les 5 premières fiches pour vérification

    rappels_produits_alimentaires_d_actualite = []
    for fiche in data:
        if fiche.get("categorie_produit") == "alimentation":
            if fiche.get("date_de_fin_de_la_procedure_de_rappel") is None or fiche.get("date_de_fin_de_la_procedure_de_rappel") == "":
                
                rappels_produits_alimentaires_d_actualite.append(fiche)

    print(f"[+] {len(rappels_produits_alimentaires_d_actualite)} fiches alimentaires")
    print(rappels_produits_alimentaires_d_actualite[0:5]) 
    
    list_rappels_mongo = []
    for fiche in rappels_produits_alimentaires_d_actualite:
        fiche_rappel = {
        "nom" :  fiche.get("libelle"),
        "marque" :  fiche.get("marque_produit"),
        "motif_rappel"  : fiche.get("motif_rappel"),
        "conseils" : fiche.get("conduites_a_tenir_par_le_consommateur"),
        "images" : fiche.get("liens_vers_les_images"),
        "affichette_pdf" : fiche.get("lien_vers_affichette_pdf"),
        "fiche_rappel_lien" : fiche.get("lien_vers_la_fiche_rappel"),
        "Preconisation_sanitaire" : fiche.get("preconisations_sanitaires"),
        }

        list_rappels_mongo.append(fiche_rappel)

    
    client = MongoClient("mongodb://localhost:27017")
    db = client["nutriwiser_db"]
    collection = db["rappels_produits_alimentaires"]
    collection.insert_many(list_rappels_mongo)
    print(f"[+] {collection.count_documents({})} fiches insérées dans la base de données MongoDB")
# Out:
# [+] Téléchargement des rappels...
# [+] 14277 fiches récupérées
# ...

# %%
# 'numero_fiche': '2024-08-0040', 
# 'numero_version': 1, 
# 'nature_juridique_rappel': 'volontaire (sans arrêté préfectoral)', 
# 'categorie_produit': 'alimentation', 
# 'sous_categorie_produit': 'autres', 
# 'marque_produit': 'belle aude', 
# 'modeles_ou_references': 'belle aude glace caramel 356g¤belle aude glace cafe 356g¤', *
# 'identification_produits': '3760015740014$24113$date de consommation recommandée$2026-04-01$|3760015740038$24123$date de consommation recommandée$2026-05-01$', 
# 'conditionnements': None, 
# 'date_debut_commercialisation': None, 
# 'date_date_fin_commercialisation': None, 
# 'temperature_conservation': 'produit à conserver au congélateur', 
# 'marque_salubrite': None, 
# 'informations_complementaires': None, 
# 'zone_geographique_de_vente': 'saint lys', 
# 'distributeurs': 'intermarche', 
# 'motif_rappel': 'rupture de la chaine du froid lors du transport', 
# 'risques_encourus': 'autre risque',
# 'preconisations_sanitaires': None,
# 'description_complementaire_risque': None, 
# 'conduites_a_tenir_par_le_consommateur': 'ne plus consommer|ne plus utiliser le produit|rapporter le produit au point de vente',
# 'numero_contact': None, 
# 'modalites_de_compensation': 'remboursement',
# 'date_de_fin_de_la_procedure_de_rappel': None, 
# 'informations_complementaires_publiques': None, 
# 'liens_vers_les_images': 'https://rappel.conso.gouv.fr/image/f9114afc-95fa-4d2d-a14e-5809a4fc916c.jpg',
# 'lien_vers_la_liste_des_produits': None, 
# 'lien_vers_la_liste_des_distributeurs': None, 
# 'lien_vers_affichette_pdf': 'https://rappel.conso.gouv.fr/affichettepdf/15308/interne', 
# 'lien_vers_la_fiche_rappel': 'https://rappel.conso.gouv.fr/fiche-rappel/15308/interne', 

# 'rappel_guid': 'c94146bb-6d10-4237-b18a-e1eaeef0e2b6', 
# 'date_publication': '2024-08-05T09:14:42+00:00', 
# 'libelle': 'cremes glacees belle aude plusieurs references', 'id': 15308}, 
# {'numero_fiche': '2024-08-0125', 
#  'numero_version': 1, 
#  'nature_juridique_rappel': 
#  'volontaire (sans arrêté préfectoral)', 
#  'categorie_produit': 'alimentation', 
#  'sous_categorie_produit': 'lait et produits laitiers', 'marque_produit': 'sans marque', 'modeles_ou_references': 'fromage de chèvre au lait pasteurisé de lots du 16/07 au 07/08', 'identification_produits': '$29/07$non concerné$$|$30/07$non concerné$$', 'conditionnements': None, 'date_debut_commercialisation': None, 'date_date_fin_commercialisation': None, 'temperature_conservation': 'produit à conserver au réfrigérateur', 'marque_salubrite': None, 'informations_complementaires': None, 'zone_geographique_de_vente': 'aude (11)', 'distributeurs': 'aucun', 'motif_rappel': 'salmonelle', 'risques_encourus': 'salmonella spp (agent responsable de la salmonellose)', 'preconisations_sanitaires': "les toxi-infections alimentaires causées par les salmonelles se traduisent par des troubles gastro-intestinaux (diarrhée, vomissements) d'apparition brutale souvent accompagnés de fièvre et de maux de tête qui surviennent généralement 6h à 72h après la consommation des produits contaminés.  ces symptômes peuvent être plus prononcés chez les jeunes enfants, les femmes enceintes, les sujets immunodéprimés et les personnes âgées. les personnes qui auraient consommé ces produits et qui présenteraient ces symptômes sont invitées à consulter leur médecin traitant en lui signalant cette consommation. en l'absence de symptômes dans les 7 jours après la consommation des produits concernés, il est inutile de s'inquiéter et de consulter un médecin. si le produit doit subir une cuisson avant consommation\xa0: la cuisson à cœur des produits (œufs durs, pâtisseries, viandes de volailles…) à +65°c permet de détruire ces bactéries et de prévenir les conséquences d'une telle contamination.", 'description_complementaire_risque': None, 'conduites_a_tenir_par_le_consommateur': 'ne plus consommer', 'numero_contact': '0674375457', 'modalites_de_compensation': 'remboursement', 'date_de_fin_de_la_procedure_de_rappel': None, 'informations_complementaires_publiques': None, 'liens_vers_les_images': 'https://rappel.conso.gouv.fr/image/f3356d86-88a4-41cb-b57a-5fb06fa34651.jpg', 'lien_vers_la_liste_des_produits': None, 'lien_vers_la_liste_des_distributeurs': None, 'lien_vers_affichette_pdf': 'https://rappel.conso.gouv.fr/affichettepdf/15397/interne', 'lien_vers_la_fiche_rappel': 'https://rappel.conso.gouv.fr/fiche-rappel/15397/interne', 'rappel_guid': '9f6ed9af-c043-43ac-8f95-6f3b6b6a2a82', 'date_publication': '2024-08-09T13:59:45+00:00', 'libelle': 'fromage de chèvre', 'id': 15397}, {'numero_fiche': '2024-09-0117', 'numero_version': 1, 'nature_juridique_rappel': 'volontaire (sans arrêté préfectoral)', 'categorie_produit': 'alimentation', 'sous_categorie_produit': 'viandes', 'marque_produit': 'côte croc', 'modeles_ou_references': 'escalopes cordons bleus de poulet x2 - 200g -côte croc', 'identification_produits': '3564700721766$29024246$date limite de consommation$2024-09-27$', 'conditionnements': None, 'date_debut_commercialisation': '2024-09-03', 'date_date_fin_commercialisation': '2024-09-16', 'temperature_conservation': 'produit à conserver au réfrigérateur', 'marque_salubrite': '29.236.010 ce', 'informations_complementaires': 'présence de corps étrangers + encre dans des escalopes cordons bleus de poulet x2 - 200g -côte croc', 'zone_geographique_de_vente': 'france entière', 'distributeurs': 'scamark', 'motif_rappel': 'présence de corps étrangers + encre dans des escalopes cordons bleus de poulet x2 - 200g -côte croc', 'risques_encourus': "inertes (verre, métal, plastique, papier, textile…)|anomalie d'étiquetage", 'preconisations_sanitaires': "en raison du risque de blessures / effets indésirables suite à l'ingestion de ce produit, par précaution il est recommandé aux personnes qui détiendraient des produits appartenant au(x) lot(s) décrit(s) ci-dessus de ne pas les consommer.", 'description_complementaire_risque': 'présence de corps étrangers + encre dans des escalopes cordons bleus de poulet x2 - 200g -côte croc', 'conduites_a_tenir_par_le_consommateur': 'ne plus consommer|détruire le produit', 'numero_contact': None, 'modalites_de_compensation': 'autre (voir informations complémentaires)', 'date_de_fin_de_la_procedure_de_rappel': None, 'informations_complementaires_publiques': 'présence de corps étrangers + encre dans des escalopes cordons bleus de poulet x2 - 200g -côte croc', 'liens_vers_les_images': 'https://rappel.conso.gouv.fr/image/5eded0b2-90ee-4192-a204-87bbde81f9e2.jpg', 'lien_vers_la_liste_des_produits': None, 'lien_vers_la_liste_des_distributeurs': 'https://rappel.conso.gouv.fr/document/3abe3438-aad4-4d25-8abd-6ae3f561cc40/interne/listedesdistributeurs', 'lien_vers_affichette_pdf': 'https://rappel.conso.gouv.fr/affichettepdf/15804/interne', 'lien_vers_la_fiche_rappel': 'https://rappel.conso.gouv.fr/fiche-rappel/15804/interne', 'rappel_guid': 'c694212d-e7c5-41e8-ac03-3d99f15c131b', 'date_publication': '2024-09-16T18:56:35+00:00', 'libelle': 'escalopes cordons bleus de poulet x2 - 200g -côte croc', 'id': 15804}, {'numero_fiche': '2024-10-0110', 'numero_version': 1, 'nature_juridique_rappel': 'volontaire (sans arrêté préfectoral)', 'categorie_produit': 'alimentation', 'sous_categorie_produit': 'fruits et légumes', 'marque_produit': 'georges helfer', 'modeles_ou_references': 'filet 500 g de limes', 'identification_produits': '3324286085122$br34280-filet 500 g leclerc$non concerné$$|3242860031016$br34280-filet 500 g carrefour$non concerné$$|3458461073748$br34280-filet 500 g intermarché$non concerné$$', 'conditionnements': 'filet 500g', 'date_debut_commercialisation': '2024-09-23', 'date_date_fin_commercialisation': '2024-10-08', 'temperature_conservation': 'produit à conserver à température ambiante', 'marque_salubrite': None, 'informations_complementaires': None, 'zone_geographique_de_vente': 'france entière', 'distributeurs': 'leclerc carrefour intermarché', 'motif_rappel': 'dépassement du seuil réglementaire de pesticides', 'risques_encourus': 'dépassement des limites autorisées de pesticides', 'preconisations_sanitaires': None, 'description_complementaire_risque': None, 'conduites_a_tenir_par_le_consommateur': 'ne plus consommer|détruire le produit', 'numero_contact': None, 'modalites_de_compensation': 'autre (voir informations complémentaires)', 'date_de_fin_de_la_procedure_de_rappel': None, 'informations_complementaires_publiques': 'selon modalité du magasin', 'liens_vers_les_images': 'https://rappel.conso.gouv.fr/image/84309401-fb4c-4c2c-9c7c-c17bf6e4aa60.jpg', 'lien_vers_la_liste_des_produits': None, 'lien_vers_la_liste_des_distributeurs': None, 'lien_vers_affichette_pdf': 'https://rappel.conso.gouv.fr/affichettepdf/16139/interne', 'lien_vers_la_fiche_rappel': 'https://rappel.conso.gouv.fr/fiche-rappel/16139/interne', 'rappel_guid': 'e34f4491-45b0-478b-924d-cfc430e636f3', 'date_publication': '2024-10-10T13:27:07+00:00', 'libelle': 'lime tahiti bresil', 'id': 16139}, {'numero_fiche': '2025-01-0117', 'numero_version': 1, 'nature_juridique_rappel': 'volontaire (sans arrêté préfectoral)', 'categorie_produit': 'alimentation', 'sous_categorie_produit': 'lait et produits laitiers', 'marque_produit': 'ferme de la noë', 'modeles_ou_references': 'lait cru entier', 'identification_produits': '3760002445007$26/02$date limite de consommation$2025-02-26$', 'conditionnements': None, 'date_debut_commercialisation': '2025-01-21', 'date_date_fin_commercialisation': '2025-01-26', 'temperature_conservation': 'produit à conserver au réfrigérateur', 'marque_salubrite': None, 'informations_complementaires': None, 'zone_geographique_de_vente': 'argentan', 'distributeurs': 'leclerc argentan', 'motif_rappel': 'erreur de dlc : il faut lire 26/01 au lieu de 26/02', 'risques_encourus': "anomalie d'étiquetage", 'preconisations_sanitaires': None, 'description_complementaire_risque': None, 'conduites_a_tenir_par_le_consommateur': 'rapporter le produit au point de vente', 'numero_contact': '0601979149', 'modalites_de_compensation': 'remboursement|echange', 'date_de_fin_de_la_procedure_de_rappel': None, 'informations_complementaires_publiques': None, 'liens_vers_les_images': 'https://rappel.conso.gouv.fr/image/785338cf-1b7d-4ab9-a360-cc4cc232134f.jpg', 'lien_vers_la_liste_des_produits': None, 'lien_vers_la_liste_des_distributeurs': None, 'lien_vers_affichette_pdf': 'https://rappel.conso.gouv.fr/affichettepdf/17172/interne', 'lien_vers_la_fiche_rappel': 'https://rappel.conso.gouv.fr/fiche-rappel/17172/interne', 'rappel_guid': '04489734-6034-4686-8552-2034f66bfbb2', 'date_publication': '2025-01-21T14:31:00+00:00', 'libelle': 'lait cru entier', 'id': 17172}]
